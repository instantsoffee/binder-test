# %%
import pandas as pd

# %%
df = pd.read_csv('pamphlets_1848.csv')

# %%
df.head()
# Out:
#          mms_id      barcode         signature  location  urns  snISBN  \
# 0  9.900496e+17  +Z171377605  F 015687-A.Kopie  ALT FLUG   NaN     NaN
# 1  9.900496e+17  +Z17137690X        F 015702-B  ALT FLUG   NaN     NaN
# 2  9.900496e+17  +Z171377009        F 015703-B  ALT FLUG   NaN     NaN
# 3  9.900495e+17  +Z171377101        F 015704-C  ALT FLUG   NaN     NaN
# 4  9.900491e+17  +Z171377204        F 015677-A  ALT FLUG   NaN     NaN
#
#    snISSN volumeNumber languages  \
# 0     NaN          NaN       ger
# 1     NaN          NaN       ger
# 2     NaN          NaN       ger
# 3     NaN          NaN       ger
# 4     NaN          NaN       ger
#
#                                           main_title  ...  \
# 0  Herr Minister! Die durch die Constitution gara...  ...
# 1                          Allgemeine Theaterzeitung  ...
# 2               Besondere Beilage zur Wiener Zeitung  ...
# 3                    Kundmachung [Wien, 1. Mai 1848]  ...
# ...

# %%
df.sample(5)
# Out:
#             mms_id      barcode   signature  location  urns  snISBN  snISSN  \
# 1538  9.900500e+17  +Z219167907  F 017340-C  ALT FLUG   NaN     NaN     NaN
# 1404  9.900500e+17  +Z219151304  F 017205-C  ALT FLUG   NaN     NaN     NaN
# 1478  9.900500e+17  +Z219161802  F 017280-A  ALT FLUG   NaN     NaN     NaN
# 1468  9.900500e+17  +Z219160500  F 017270-B  ALT FLUG   NaN     NaN     NaN
# 747   9.900497e+17  +Z227453305  F 016447-C  ALT FLUG   NaN     NaN     NaN
#
#      volumeNumber languages  \
# 1538          NaN       ger
# 1404          NaN       ger
# 1478          NaN       ger
# 1468          NaN       ger
# 747           NaN       ger
#
#                                              main_title  ...  \
# 1538  Für Jedermann zu wissen nothwendig! Der Kampf ...  ...
# 1404  Der österreichische Patrioten-Verein! Erste Ku...  ...
# 1478  Circulare des kaiserl. königl. steiermärkische...  ...
# 1468  Der Redacteur der schwarzgelben Geißel. Die sc...  ...
# ...
